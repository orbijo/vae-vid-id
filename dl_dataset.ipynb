# %%
# import kagglehub

# Download latest version
# path = kagglehub.dataset_download("matthewjansen/ucf101-action-recognition")

# print("Path to dataset files:", path)

# %%
import pandas as pd

data_path = "data/"
data_file = "panda70m_training_2m.csv"
data = pd.read_csv(data_path + data_file)
data.head(10)
# Out:
#        videoID                                          url  \
# 0  ---4IxR2xOg  https://www.youtube.com/watch?v=---4IxR2xOg
# 1  ---7zZh4oZk  https://www.youtube.com/watch?v=---7zZh4oZk
# 2  ---Tt_FYlTQ  https://www.youtube.com/watch?v=---Tt_FYlTQ
# 3  ---azc0s53U  https://www.youtube.com/watch?v=---azc0s53U
# 4  ---dI8zrQJI  https://www.youtube.com/watch?v=---dI8zrQJI
# 5  --0EdaCtR_4  https://www.youtube.com/watch?v=--0EdaCtR_4
# 6  --0G4wPymVw  https://www.youtube.com/watch?v=--0G4wPymVw
# 7  --14U7iEJ1U  https://www.youtube.com/watch?v=--14U7iEJ1U
# 8  --1GL5dLrYI  https://www.youtube.com/watch?v=--1GL5dLrYI
# 9  --27AXZqb7A  https://www.youtube.com/watch?v=--27AXZqb7A
#
#                                            timestamp  \
# 0  [['0:00:16.300', '0:00:32.566'], ['0:00:44.100...
# 1  [['0:00:14.160', '0:00:16.440'], ['0:00:26.240...
# 2  [['0:00:01.067', '0:00:09.876'], ['0:01:07.067...
# 3  [['0:00:50.560', '0:00:57.280'], ['0:01:58.800...
# ...
